# %% [markdown]
# # Dealing with imbalanced dataset

# %% [markdown]
# Imbalanced dataset
#
# How to resolve imbalancing
#
#       Upsampling
#
#       Downsampling
#
# Introduce KNearest Neighbor
#
# HYper parameter tuning using GridSearchCV
#
# Create the best model
#
# Conclude

# %% [markdown]
# ## Imbalanced dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
bank=pd.read_csv('bank.csv')

# %%
bank
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45208   72       retired   married  secondary      no     5715      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
# ...

# %%
bank['y'].value_counts()
# Out:
# no     39922
# yes     5289
# Name: y, dtype: int64

# %%
5289/(5289+39922)
# Out:
# 0.11698480458295547

# %% [markdown]
# Two classes:
#
# Yes, class. >>> 11.7%
#
# No, class >>>> 88.3%
#
# This is an imabalanced dataset

# %% [markdown]
# ## Resolving imbalancing
#
# ### Upsampling
#
# ### Downsampling

# %% [markdown]
# ## Splitting the data

# %%
bank_no=bank[bank['y']=='no']
bank_no.shape
# Out:
# (39922, 17)

# %%
bank_no.head(25)
# Out:
#     age           job   marital  education default  balance housing loan  \
# 0    58    management   married   tertiary      no     2143     yes   no
# 1    44    technician    single  secondary      no       29     yes   no
# 2    33  entrepreneur   married  secondary      no        2     yes  yes
# 3    47   blue-collar   married    unknown      no     1506     yes   no
# 4    33       unknown    single    unknown      no        1      no   no
# 5    35    management   married   tertiary      no      231     yes   no
# 6    28    management    single   tertiary      no      447     yes  yes
# 7    42  entrepreneur  divorced   tertiary     yes        2     yes   no
# 8    58       retired   married    primary      no      121     yes   no
# 9    43    technician    single  secondary      no      593     yes   no
# 10   41        admin.  divorced  secondary      no      270     yes   no
# 11   29        admin.    single  secondary      no      390     yes   no
# ...

# %%
bank_yes=bank[bank['y']=='yes']
bank_yes.shape
# Out:
# (5289, 17)

# %%
bank_yes.head(25)
# Out:
#       age          job   marital  education default  balance housing loan  \
# 83     59       admin.   married  secondary      no     2343     yes   no
# 86     56       admin.   married  secondary      no       45      no   no
# 87     41   technician   married  secondary      no     1270     yes   no
# 129    55     services   married  secondary      no     2476     yes   no
# 168    54       admin.   married   tertiary      no      184      no   no
# 270    42   management    single   tertiary      no        0     yes  yes
# 388    56   management   married   tertiary      no      830     yes  yes
# 390    60      retired  divorced  secondary      no      545     yes   no
# 446    39   technician    single    unknown      no    45248     yes   no
# 457    37   technician   married  secondary      no        1     yes   no
# 474    34       admin.   married  secondary      no      869      no   no
# 512    55   unemployed  divorced  secondary      no      387     yes   no
# ...

# %% [markdown]
# ## Upsampling

# %%
from sklearn.utils import resample

bank_yes_up=resample(bank_yes,n_samples=15000,replace=True,random_state=100)

bank_yes_up.head(25)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 42571   38        admin.   married  secondary      no    11303      no   no
# 3190    41   blue-collar   married  secondary      no     1384     yes   no
# 10049   42  entrepreneur   married   tertiary      no     5345      no   no
# 31962   31   blue-collar   married  secondary      no     1406     yes  yes
# 43024   51    management   married   tertiary      no      346      no   no
# 18015   55    management   married   tertiary      no     -375      no   no
# 44802   31    management    single   tertiary      no     3340      no   no
# 39724   43        admin.   married  secondary      no      132      no   no
# 43431   78       retired  divorced    primary      no     1389      no   no
# 31180   25    technician    single  secondary      no     1231     yes   no
# 41153   67       retired  divorced   tertiary      no      443      no   no
# ...

# %%
bank_yes_up.shape
# Out:
# (15000, 17)

# %% [markdown]
# ## Downsampling
#
# On majority dataset
#
# It reduces the contribution

# %%
bank_no_down=resample(bank_no,replace=False,n_samples=25000,random_state=100)
bank_no_down.shape
# Out:
# (25000, 17)

# %%
bank_no_down.head(25)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 9789    39   blue-collar   married   tertiary      no    10483      no   no
# 44899   77       retired   married   tertiary      no        0      no   no
# 2331    28   blue-collar   married  secondary      no      -95     yes   no
# 15271   41    management    single   tertiary      no        0     yes   no
# 10642   38      services  divorced  secondary      no      439      no   no
# 31346   57   blue-collar   married    primary      no     1610      no   no
# 15867   41   blue-collar   married  secondary     yes     -750     yes  yes
# 24316   48    technician   married  secondary      no       32     yes  yes
# 2401    27   blue-collar    single  secondary      no       71     yes   no
# 8299    47        admin.   married    primary      no       68     yes   no
# 28154   26    technician    single  secondary      no      152      no  yes
# ...

# %% [markdown]
# ## Creating a new dataset

# %%
bank_new=pd.concat([bank_no_down,bank_yes_up])
bank_new.shape
# Out:
# (40000, 17)

# %%
bank_new.head(25)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 9789    39   blue-collar   married   tertiary      no    10483      no   no
# 44899   77       retired   married   tertiary      no        0      no   no
# 2331    28   blue-collar   married  secondary      no      -95     yes   no
# 15271   41    management    single   tertiary      no        0     yes   no
# 10642   38      services  divorced  secondary      no      439      no   no
# 31346   57   blue-collar   married    primary      no     1610      no   no
# 15867   41   blue-collar   married  secondary     yes     -750     yes  yes
# 24316   48    technician   married  secondary      no       32     yes  yes
# 2401    27   blue-collar    single  secondary      no       71     yes   no
# 8299    47        admin.   married    primary      no       68     yes   no
# 28154   26    technician    single  secondary      no      152      no  yes
# ...

# %%
bank_new.tail(25)
# Out:
#        age            job  marital  education default  balance housing loan  \
# 44474   47     management  married   tertiary      no     2306      no   no
# 40456   25         admin.   single  secondary      no      285      no   no
# 33943   29        student   single  secondary      no      314      no   no
# 42457   49     technician  married  secondary      no      307      no   no
# 43416   30     management  married   tertiary      no      102     yes   no
# 41849   27     management  married   tertiary      no      893      no   no
# 4916    37     technician   single  secondary      no     1211     yes   no
# 2882    40         admin.  married  secondary      no     1535     yes   no
# 33704   35     management   single   tertiary      no      704      no   no
# 39780   26     management   single  secondary      no     2613      no   no
# 33803   72        retired  married    primary      no      763      no   no
# ...

# %% [markdown]
# ## Shuffling the data

# %%
from sklearn.utils import shuffle

bank_new=shuffle(bank_new)
bank_new.head(25)
# Out:
#        age           job  marital  education default  balance housing loan  \
# 23153   38    technician  married   tertiary      no     -363      no   no
# 14938   42      services  married  secondary      no     3465     yes  yes
# 4986    33    technician   single  secondary      no      296     yes   no
# 22002   30    technician   single  secondary      no      790      no   no
# 15922   35    technician  married  secondary      no      561     yes   no
# 33793   51    management  married   tertiary      no     4917      no   no
# 23248   53    unemployed  married    primary      no       49      no   no
# 15538   34    technician  married  secondary      no     6324     yes   no
# 44808   36    technician  married   tertiary      no      376      no   no
# 1520    37    unemployed   single  secondary      no      381     yes   no
# 41554   73       retired  married    unknown      no      739      no   no
# ...

# %% [markdown]
# ## Separating to target and features

# %%
# Target
y=bank_new['y']
y
# Out:
# 23153     no
# 14938    yes
# 4986      no
# 22002     no
# 15922     no
#         ...
# 42941    yes
# 10094     no
# 5476      no
# 43460    yes
# 15957     no
# Name: y, Length: 40000, dtype: object

# %%
# Features

X=bank_new.drop(['y'],axis=1)
X
# Out:
#        age         job   marital  education default  balance housing loan  \
# 23153   38  technician   married   tertiary      no     -363      no   no
# 14938   42    services   married  secondary      no     3465     yes  yes
# 4986    33  technician    single  secondary      no      296     yes   no
# 22002   30  technician    single  secondary      no      790      no   no
# 15922   35  technician   married  secondary      no      561     yes   no
# ...    ...         ...       ...        ...     ...      ...     ...  ...
# 42941   45      admin.   married  secondary      no     1206      no   no
# 10094   53     retired  divorced  secondary      no      -24      no   no
# 5476    39  technician  divorced  secondary      no     1222     yes   no
# 43460   30  management    single   tertiary      no     3779      no   no
# 15957   33  technician    single   tertiary      no     1257     yes   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome
# ...

# %% [markdown]
# ## Converting categorical features to numeric

# %%
X_new=pd.get_dummies(X)
X_new
# Out:
#        age  balance  day  duration  campaign  pdays  previous  job_admin.  \
# 23153   38     -363   26       101         2     -1         0           0
# 14938   42     3465   16      1039         2     -1         0           0
# 4986    33      296   21       226         1     -1         0           0
# 22002   30      790   20       696         3     -1         0           0
# 15922   35      561   22        95         1     -1         0           0
# ...    ...      ...  ...       ...       ...    ...       ...         ...
# 42941   45     1206    8       309         1    446         3           1
# 10094   53      -24   11       303         1     -1         0           0
# 5476    39     1222   23       451         4     -1         0           0
# 43460   30     3779   13      1093         1     -1         0           0
# 15957   33     1257   22        66         1     -1         0           0
#
#        job_blue-collar  job_entrepreneur  ...  month_jun  month_mar  \
# ...

# %% [markdown]
# ## Standardisation of features

# %%
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()

X_scaled=scaler.fit_transform(X_new)
X_scaled
# Out:
# array([[-0.27256415, -0.55825794,  1.23230374, ..., -0.21921049,
#         -0.28888227,  0.55166443],
#        [ 0.07458499,  0.58157581,  0.04131826, ..., -0.21921049,
#         -0.28888227,  0.55166443],
#        [-0.70650057, -0.36203265,  0.636811  , ..., -0.21921049,
#         -0.28888227,  0.55166443],
#        ...,
#        [-0.18577686, -0.08630484,  0.87500809, ..., -0.21921049,
#         -0.28888227,  0.55166443],
#        [-0.96686243,  0.67507314, -0.31597738, ..., -0.21921049,
#         -0.28888227,  0.55166443],
#        [-0.70650057, -0.07588316,  0.75590955, ..., -0.21921049,
#         -0.28888227,  0.55166443]])

# %% [markdown]
# ## Splitting to train and test

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test=train_test_split(X_scaled,y,test_size=0.2,random_state=100)

X_train.shape,X_test.shape,y_train.shape,y_test.shape
# Out:
# ((32000, 51), (8000, 51), (32000,), (8000,))

# %% [markdown]
# ## Model building - K Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier

knn=KNeighborsClassifier()

knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# ## Performance analysis

# %%
from sklearn.metrics import confusion_matrix, classification_report

report=classification_report(y_test, knn.predict(X_test))
cm=confusion_matrix(y_test, knn.predict(X_test))

print(' The CM:\n', cm)
print(' The report:\n', report)
# Out:
#  The CM:
#  [[4340  677]
#  [ 565 2418]]
#  The report:
#                precision    recall  f1-score   support
#
#           no       0.88      0.87      0.87      5017
#          yes       0.78      0.81      0.80      2983
#
#     accuracy                           0.84      8000
#    macro avg       0.83      0.84      0.84      8000
# weighted avg       0.85      0.84      0.85      8000

# %% [markdown]
# ## Hyper parameter tuning using GridSearchCV

# %%
from sklearn.model_selection import GridSearchCV

knn_gs=GridSearchCV(knn, {'n_neighbors': range(2,8)})

# %%
knn_gs.fit(X_train,y_train)
# Out:
# GridSearchCV(estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(2, 8)})

# %%
knn_gs.best_params_
# Out:
# {'n_neighbors': 2}

# %% [markdown]
# ## Building the best model

# %%
knn_best=KNeighborsClassifier(n_neighbors=2)
knn_best.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %%
report=classification_report(y_test,knn_best.predict(X_test))

print(' Report:\n', report)
# Out:
#  Report:
#                precision    recall  f1-score   support
#
#           no       0.89      0.92      0.90      5017
#          yes       0.86      0.81      0.83      2983
#
#     accuracy                           0.88      8000
#    macro avg       0.87      0.86      0.87      8000
# weighted avg       0.88      0.88      0.88      8000
